# %% [markdown]
# #Abrir drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Importar bibliotecas

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
from torchvision import datasets
from torchvision.models import mobilenetv2, MobileNet_V2_Weights
from torch.optim import lr_scheduler
from torch.utils.data import random_split

# %%
import pandas as pd
import numpy as np
import os
import shutil
from tqdm.notebook import tqdm
from pathlib import Path
import cv2
import random

# %%
import time
from PIL import Image
from tempfile import TemporaryDirectory
import matplotlib.pyplot as plt
import time
import copy

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Definir seed

# %%
np.random.seed(42)
random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
g = torch.Generator()
g.manual_seed(42)

# %% [markdown]
# #Preparação dos arquivos

# %% [markdown]
# ## Abrir os arquivos

# %%
# !cp /content/drive/MyDrive/Upx_plantas/general_dataset.zip /content

# %%
# !unzip general_dataset.zip
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: general_dataset/train/nao_folhas/000000275058.jpg
#   inflating: general_dataset/train/nao_folhas/000000275198.jpg
#   inflating: general_dataset/train/nao_folhas/000000275392.jpg
#   inflating: general_dataset/train/nao_folhas/000000275749.jpg
#   inflating: general_dataset/train/nao_folhas/000000275791.jpg
#   inflating: general_dataset/train/nao_folhas/000000276018.jpg
#   inflating: general_dataset/train/nao_folhas/000000276284.jpg
#   inflating: general_dataset/train/nao_folhas/000000276285.jpg
#   inflating: general_dataset/train/nao_folhas/000000276434.jpg
#   inflating: general_dataset/train/nao_folhas/000000276720.jpg
#   inflating: general_dataset/train/nao_folhas/000000276804.jpg
#   inflating: general_dataset/train/nao_folhas/000000277005.jpg
#   inflating: general_dataset/train/nao_folhas/000000277020.jpg
#   inflating: general_dataset/train/nao_folhas/000000277051.jpg
#   inflating: general_dataset/train/nao_folhas/000000277197.jpg
#   inflating: general_dataset/train/nao_folhas/000000277584.jpg
#   inflating: general_dataset/train/nao_folhas/000000277689.jpg
#   inflating: general_dataset/train/nao_folhas/000000278353.jpg
#   inflating: general_dataset/train/nao_folhas/000000278463.jpg
#   inflating: general_dataset/train/nao_folhas/000000278749.jpg
#   inflating: general_dataset/train/nao_folhas/000000278848.jpg
#   inflating: general_dataset/train/nao_folhas/000000278973.jpg
#   inflating: general_dataset/train/nao_folhas/000000279145.jpg
#   inflating: general_dataset/train/nao_folhas/000000279278.jpg
#   inflating: general_dataset/train/nao_folhas/000000279714.jpg
#   inflating: general_dataset/train/nao_folhas/000000279769.jpg
#   inflating: general_dataset/train/nao_folhas/000000279774.jpg
#   inflating: general_dataset/train/nao_folhas/000000279887.jpg
#   inflating: general_dataset/train/nao_folhas/000000280325.jpg
#   inflating: general_dataset/train/nao_folhas/000000280710.jpg
#   inflating: general_dataset/train/nao_folhas/000000280891.jpg
#   inflating: general_dataset/train/nao_folhas/000000280918.jpg
#   inflating: general_dataset/train/nao_folhas/000000280930.jpg
#   inflating: general_dataset/train/nao_folhas/000000281032.jpg
#   inflating: general_dataset/train/nao_folhas/000000281179.jpg
#   inflating: general_dataset/train/nao_folhas/000000281409.jpg
#   inflating: general_dataset/train/nao_folhas/000000281414.jpg
#   inflating: general_dataset/train/nao_folhas/000000281447.jpg
#   inflating: general_dataset/train/nao_folhas/000000281687.jpg
#   inflating: general_dataset/train/nao_folhas/000000281754.jpg
#   inflating: general_dataset/train/nao_folhas/000000281929.jpg
#   inflating: general_dataset/train/nao_folhas/000000282037.jpg
#   inflating: general_dataset/train/nao_folhas/000000282046.jpg
#   inflating: general_dataset/train/nao_folhas/000000282296.jpg
#   inflating: general_dataset/train/nao_folhas/000000282298.jpg
#   inflating: general_dataset/train/nao_folhas/000000282912.jpg
#   inflating: general_dataset/train/nao_folhas/000000283037.jpg
#   inflating: general_dataset/train/nao_folhas/000000283070.jpg
#   inflating: general_dataset/train/nao_folhas/000000283113.jpg
#   inflating: general_dataset/train/nao_folhas/000000283520.jpg
#   inflating: general_dataset/train/nao_folhas/000000283785.jpg
#   inflating: general_dataset/train/nao_folhas/000000284106.jpg
#   inflating: general_dataset/train/nao_folhas/000000284296.jpg
#   inflating: general_dataset/train/nao_folhas/000000284445.jpg
#   inflating: general_dataset/train/nao_folhas/000000284623.jpg
#   inflating: general_dataset/train/nao_folhas/000000284698.jpg
#   inflating: general_dataset/train/nao_folhas/000000284743.jpg
#   inflating: general_dataset/train/nao_folhas/000000285047.jpg
#   inflating: general_dataset/train/nao_folhas/000000285349.jpg
#   inflating: general_dataset/train/nao_folhas/000000285894.jpg
#   inflating: general_dataset/train/nao_folhas/000000286182.jpg
#   inflating: general_dataset/train/nao_folhas/000000286422.jpg
#   inflating: general_dataset/train/nao_folhas/000000286458.jpg
#   inflating: general_dataset/train/nao_folhas/000000286503.jpg
#   inflating: general_dataset/train/nao_folhas/000000286507.jpg
#   inflating: general_dataset/train/nao_folhas/000000286553.jpg
#   inflating: general_dataset/train/nao_folhas/000000286660.jpg
#   inflating: general_dataset/train/nao_folhas/000000286708.jpg
#   inflating: general_dataset/train/nao_folhas/000000286849.jpg
#   inflating: general_dataset/train/nao_folhas/000000286908.jpg
#   inflating: general_dataset/train/nao_folhas/000000286994.jpg
#   inflating: general_dataset/train/nao_folhas/000000287347.jpg
#   inflating: general_dataset/train/nao_folhas/000000287527.jpg
#   inflating: general_dataset/train/nao_folhas/000000287545.jpg
#   inflating: general_dataset/train/nao_folhas/000000287649.jpg
#   inflating: general_dataset/train/nao_folhas/000000287874.jpg
#   inflating: general_dataset/train/nao_folhas/000000287959.jpg
#   inflating: general_dataset/train/nao_folhas/000000288391.jpg
#   inflating: general_dataset/train/nao_folhas/000000288430.jpg
#   inflating: general_dataset/train/nao_folhas/000000288584.jpg
#   inflating: general_dataset/train/nao_folhas/000000288685.jpg
#   inflating: general_dataset/train/nao_folhas/000000288762.jpg
#   inflating: general_dataset/train/nao_folhas/000000288862.jpg
#   inflating: general_dataset/train/nao_folhas/000000288882.jpg
#   inflating: general_dataset/train/nao_folhas/000000289059.jpg
#   inflating: general_dataset/train/nao_folhas/000000289222.jpg
#   inflating: general_dataset/train/nao_folhas/000000289393.jpg
#   inflating: general_dataset/train/nao_folhas/000000289415.jpg
#   inflating: general_dataset/train/nao_folhas/000000289516.jpg
#   inflating: general_dataset/train/nao_folhas/000000289659.jpg
#   inflating: general_dataset/train/nao_folhas/000000289702.jpg
#   inflating: general_dataset/train/nao_folhas/000000289741.jpg
#   inflating: general_dataset/train/nao_folhas/000000289992.jpg
#   inflating: general_dataset/train/nao_folhas/000000290081.jpg
#   inflating: general_dataset/train/nao_folhas/000000290163.jpg
#   inflating: general_dataset/train/nao_folhas/000000290179.jpg
#   inflating: general_dataset/train/nao_folhas/000000290248.jpg
#   inflating: general_dataset/train/nao_folhas/000000290293.jpg
#   inflating: general_dataset/train/nao_folhas/000000290592.jpg
#   inflating: general_dataset/train/nao_folhas/000000290619.jpg
#   inflating: general_dataset/train/nao_folhas/000000290768.jpg
#   inflating: general_dataset/train/nao_folhas/000000290843.jpg
#   inflating: general_dataset/train/nao_folhas/000000291490.jpg
#   inflating: general_dataset/train/nao_folhas/000000291551.jpg
#   inflating: general_dataset/train/nao_folhas/000000291664.jpg
#   inflating: general_dataset/train/nao_folhas/000000291791.jpg
#   inflating: general_dataset/train/nao_folhas/000000291861.jpg
#   inflating: general_dataset/train/nao_folhas/000000292005.jpg
#   inflating: general_dataset/train/nao_folhas/000000292060.jpg
#   inflating: general_dataset/train/nao_folhas/000000292236.jpg
#   inflating: general_dataset/train/nao_folhas/000000292330.jpg
#   inflating: general_dataset/train/nao_folhas/000000292415.jpg
#   inflating: general_dataset/train/nao_folhas/000000292446.jpg
#   inflating: general_dataset/train/nao_folhas/000000292456.jpg
#   inflating: general_dataset/train/nao_folhas/000000292997.jpg
#   inflating: general_dataset/train/nao_folhas/000000293044.jpg
#   inflating: general_dataset/train/nao_folhas/000000293200.jpg
#   inflating: general_dataset/train/nao_folhas/000000293245.jpg
#   inflating: general_dataset/train/nao_folhas/000000293300.jpg
#   inflating: general_dataset/train/nao_folhas/000000293324.jpg
#   inflating: general_dataset/train/nao_folhas/000000293625.jpg
#   inflating: general_dataset/train/nao_folhas/000000293794.jpg
#   inflating: general_dataset/train/nao_folhas/000000293858.jpg
#   inflating: general_dataset/train/nao_folhas/000000294162.jpg
#   inflating: general_dataset/train/nao_folhas/000000294163.jpg
#   inflating: general_dataset/train/nao_folhas/000000294831.jpg
#   inflating: general_dataset/train/nao_folhas/000000294855.jpg
#   inflating: general_dataset/train/nao_folhas/000000295138.jpg
#   inflating: general_dataset/train/nao_folhas/000000295231.jpg
#   inflating: general_dataset/train/nao_folhas/000000295420.jpg
#   inflating: general_dataset/train/nao_folhas/000000295478.jpg
#   inflating: general_dataset/train/nao_folhas/000000295713.jpg
#   inflating: general_dataset/train/nao_folhas/000000295797.jpg
#   inflating: general_dataset/train/nao_folhas/000000295809.jpg
#   inflating: general_dataset/train/nao_folhas/000000296657.jpg
#   inflating: general_dataset/train/nao_folhas/000000296969.jpg
#   inflating: general_dataset/train/nao_folhas/000000297022.jpg
#   inflating: general_dataset/train/nao_folhas/000000297084.jpg
#   inflating: general_dataset/train/nao_folhas/000000297085.jpg
#   inflating: general_dataset/train/nao_folhas/000000297353.jpg
#   inflating: general_dataset/train/nao_folhas/000000297396.jpg
#   inflating: general_dataset/train/nao_folhas/000000297427.jpg
#   inflating: general_dataset/train/nao_folhas/000000297562.jpg
#   inflating: general_dataset/train/nao_folhas/000000297578.jpg
#   inflating: general_dataset/train/nao_folhas/000000297595.jpg
#   inflating: general_dataset/train/nao_folhas/000000297681.jpg
#   inflating: general_dataset/train/nao_folhas/000000297698.jpg
#   inflating: general_dataset/train/nao_folhas/000000297830.jpg
#   inflating: general_dataset/train/nao_folhas/000000298396.jpg
#   inflating: general_dataset/train/nao_folhas/000000298697.jpg
#   inflating: general_dataset/train/nao_folhas/000000299355.jpg
#   inflating: general_dataset/train/nao_folhas/000000299720.jpg
#   inflating: general_dataset/train/nao_folhas/000000300039.jpg
#   inflating: general_dataset/train/nao_folhas/000000300155.jpg
#   inflating: general_dataset/train/nao_folhas/000000300233.jpg
#   inflating: general_dataset/train/nao_folhas/000000300276.jpg
#   inflating: general_dataset/train/nao_folhas/000000300341.jpg
#   inflating: general_dataset/train/nao_folhas/000000300659.jpg
#   inflating: general_dataset/train/nao_folhas/000000300842.jpg
#   inflating: general_dataset/train/nao_folhas/000000300913.jpg
#   inflating: general_dataset/train/nao_folhas/000000301376.jpg
#   inflating: general_dataset/train/nao_folhas/000000301563.jpg
#   inflating: general_dataset/train/nao_folhas/000000301981.jpg
#   inflating: general_dataset/train/nao_folhas/000000302107.jpg
#   inflating: general_dataset/train/nao_folhas/000000302165.jpg
#   inflating: general_dataset/train/nao_folhas/000000302452.jpg
#   inflating: general_dataset/train/nao_folhas/000000302536.jpg
#   inflating: general_dataset/train/nao_folhas/000000302882.jpg
#   inflating: general_dataset/train/nao_folhas/000000303305.jpg
#   inflating: general_dataset/train/nao_folhas/000000303499.jpg
#   inflating: general_dataset/train/nao_folhas/000000303566.jpg
#   inflating: general_dataset/train/nao_folhas/000000303653.jpg
#   inflating: general_dataset/train/nao_folhas/000000303713.jpg
#   inflating: general_dataset/train/nao_folhas/000000303863.jpg
#   inflating: general_dataset/train/nao_folhas/000000303908.jpg
#   inflating: general_dataset/train/nao_folhas/000000304180.jpg
#   inflating: general_dataset/train/nao_folhas/000000304396.jpg
#   inflating: general_dataset/train/nao_folhas/000000304404.jpg
#   inflating: general_dataset/train/nao_folhas/000000304817.jpg
#   inflating: general_dataset/train/nao_folhas/000000304984.jpg
#   inflating: general_dataset/train/nao_folhas/000000305309.jpg
#   inflating: general_dataset/train/nao_folhas/000000305317.jpg
#   inflating: general_dataset/train/nao_folhas/000000305609.jpg
#   inflating: general_dataset/train/nao_folhas/000000305695.jpg
#   inflating: general_dataset/train/nao_folhas/000000306700.jpg
#   inflating: general_dataset/train/nao_folhas/000000306893.jpg
#   inflating: general_dataset/train/nao_folhas/000000307074.jpg
#   inflating: general_dataset/train/nao_folhas/000000307145.jpg
#   inflating: general_dataset/train/nao_folhas/000000307172.jpg
#   inflating: general_dataset/train/nao_folhas/000000307598.jpg
#   inflating: general_dataset/train/nao_folhas/000000307658.jpg
#   inflating: general_dataset/train/nao_folhas/000000308165.jpg
#   inflating: general_dataset/train/nao_folhas/000000308193.jpg
#   inflating: general_dataset/train/nao_folhas/000000308328.jpg
#   inflating: general_dataset/train/nao_folhas/000000308391.jpg
#   inflating: general_dataset/train/nao_folhas/000000308394.jpg
#   inflating: general_dataset/train/nao_folhas/000000308430.jpg
#   inflating: general_dataset/train/nao_folhas/000000308466.jpg
#   inflating: general_dataset/train/nao_folhas/000000308476.jpg
#   inflating: general_dataset/train/nao_folhas/000000308531.jpg
#   inflating: general_dataset/train/nao_folhas/000000308545.jpg
#   inflating: general_dataset/train/nao_folhas/000000308587.jpg
#   inflating: general_dataset/train/nao_folhas/000000308631.jpg
#   inflating: general_dataset/train/nao_folhas/000000308753.jpg
#   inflating: general_dataset/train/nao_folhas/000000308793.jpg
#   inflating: general_dataset/train/nao_folhas/000000308799.jpg
#   inflating: general_dataset/train/nao_folhas/000000309173.jpg
#   inflating: general_dataset/train/nao_folhas/000000309452.jpg
#   inflating: general_dataset/train/nao_folhas/000000309467.jpg
#   inflating: general_dataset/train/nao_folhas/000000309484.jpg
#   inflating: general_dataset/train/nao_folhas/000000309678.jpg
#   inflating: general_dataset/train/nao_folhas/000000309938.jpg
#   inflating: general_dataset/train/nao_folhas/000000309964.jpg
#   inflating: general_dataset/train/nao_folhas/000000310622.jpg
#   inflating: general_dataset/train/nao_folhas/000000310862.jpg
#   inflating: general_dataset/train/nao_folhas/000000311002.jpg
#   inflating: general_dataset/train/nao_folhas/000000311081.jpg
#   inflating: general_dataset/train/nao_folhas/000000311180.jpg
#   inflating: general_dataset/train/nao_folhas/000000311190.jpg
#   inflating: general_dataset/train/nao_folhas/000000311295.jpg
#   inflating: general_dataset/train/nao_folhas/000000311303.jpg
#   inflating: general_dataset/train/nao_folhas/000000311394.jpg
#   inflating: general_dataset/train/nao_folhas/000000311518.jpg
#   inflating: general_dataset/train/nao_folhas/000000311789.jpg
#   inflating: general_dataset/train/nao_folhas/000000311909.jpg
#   inflating: general_dataset/train/nao_folhas/000000311928.jpg
#   inflating: general_dataset/train/nao_folhas/000000311950.jpg
#   inflating: general_dataset/train/nao_folhas/000000312237.jpg
#   inflating: general_dataset/train/nao_folhas/000000312263.jpg
#   inflating: general_dataset/train/nao_folhas/000000312278.jpg
#   inflating: general_dataset/train/nao_folhas/000000312340.jpg
#   inflating: general_dataset/train/nao_folhas/000000312406.jpg
#   inflating: general_dataset/train/nao_folhas/000000312421.jpg
#   inflating: general_dataset/train/nao_folhas/000000312489.jpg
#   inflating: general_dataset/train/nao_folhas/000000312552.jpg
#   inflating: general_dataset/train/nao_folhas/000000312586.jpg
#   inflating: general_dataset/train/nao_folhas/000000313034.jpg
#   inflating: general_dataset/train/nao_folhas/000000313130.jpg
#   inflating: general_dataset/train/nao_folhas/000000313182.jpg
#   inflating: general_dataset/train/nao_folhas/000000313454.jpg
#   inflating: general_dataset/train/nao_folhas/000000313562.jpg
#   inflating: general_dataset/train/nao_folhas/000000313588.jpg
#   inflating: general_dataset/train/nao_folhas/000000314034.jpg
#   inflating: general_dataset/train/nao_folhas/000000314177.jpg
#   inflating: general_dataset/train/nao_folhas/000000314251.jpg
#   inflating: general_dataset/train/nao_folhas/000000314294.jpg
#   inflating: general_dataset/train/nao_folhas/000000314709.jpg
#   inflating: general_dataset/train/nao_folhas/000000314914.jpg
#   inflating: general_dataset/train/nao_folhas/000000315001.jpg
#   inflating: general_dataset/train/nao_folhas/000000315187.jpg
#   inflating: general_dataset/train/nao_folhas/000000315257.jpg
#   inflating: general_dataset/train/nao_folhas/000000315450.jpg
#   inflating: general_dataset/train/nao_folhas/000000315492.jpg
#   inflating: general_dataset/train/nao_folhas/000000316015.jpg
#   inflating: general_dataset/train/nao_folhas/000000316054.jpg
#   inflating: general_dataset/train/nao_folhas/000000316404.jpg
#   inflating: general_dataset/train/nao_folhas/000000316666.jpg
#   inflating: general_dataset/train/nao_folhas/000000317024.jpg
#   inflating: general_dataset/train/nao_folhas/000000317433.jpg
#   inflating: general_dataset/train/nao_folhas/000000318080.jpg
#   inflating: general_dataset/train/nao_folhas/000000318114.jpg
#   inflating: general_dataset/train/nao_folhas/000000318455.jpg
#   inflating: general_dataset/train/nao_folhas/000000319100.jpg
#   inflating: general_dataset/train/nao_folhas/000000319184.jpg
#   inflating: general_dataset/train/nao_folhas/000000319369.jpg
#   inflating: general_dataset/train/nao_folhas/000000319534.jpg
#   inflating: general_dataset/train/nao_folhas/000000319607.jpg
#   inflating: general_dataset/train/nao_folhas/000000319617.jpg
#   inflating: general_dataset/train/nao_folhas/000000319721.jpg
#   inflating: general_dataset/train/nao_folhas/000000320232.jpg
#   inflating: general_dataset/train/nao_folhas/000000320425.jpg
#   inflating: general_dataset/train/nao_folhas/000000320490.jpg
#   inflating: general_dataset/train/nao_folhas/000000320554.jpg
#   inflating: general_dataset/train/nao_folhas/000000320632.jpg
#   inflating: general_dataset/train/nao_folhas/000000320642.jpg
#   inflating: general_dataset/train/nao_folhas/000000320664.jpg
#   inflating: general_dataset/train/nao_folhas/000000320696.jpg
#   inflating: general_dataset/train/nao_folhas/000000320706.jpg
#   inflating: general_dataset/train/nao_folhas/000000321118.jpg
#   inflating: general_dataset/train/nao_folhas/000000321214.jpg
#   inflating: general_dataset/train/nao_folhas/000000321333.jpg
#   inflating: general_dataset/train/nao_folhas/000000321557.jpg
#   inflating: general_dataset/train/nao_folhas/000000321790.jpg
#   inflating: general_dataset/train/nao_folhas/000000322163.jpg
#   inflating: general_dataset/train/nao_folhas/000000322211.jpg
#   inflating: general_dataset/train/nao_folhas/000000322352.jpg
#   inflating: general_dataset/train/nao_folhas/000000322429.jpg
#   inflating: general_dataset/train/nao_folhas/000000322574.jpg
#   inflating: general_dataset/train/nao_folhas/000000322610.jpg
#   inflating: general_dataset/train/nao_folhas/000000322829.jpg
#   inflating: general_dataset/train/nao_folhas/000000322844.jpg
#   inflating: general_dataset/train/nao_folhas/000000322944.jpg
#   inflating: general_dataset/train/nao_folhas/000000322959.jpg
#   inflating: general_dataset/train/nao_folhas/000000322968.jpg
#   inflating: general_dataset/train/nao_folhas/000000323355.jpg
#   inflating: general_dataset/train/nao_folhas/000000323496.jpg
#   inflating: general_dataset/train/nao_folhas/000000323571.jpg
#   inflating: general_dataset/train/nao_folhas/000000323751.jpg
#   inflating: general_dataset/train/nao_folhas/000000323799.jpg
#   inflating: general_dataset/train/nao_folhas/000000324158.jpg
#   inflating: general_dataset/train/nao_folhas/000000324614.jpg
#   inflating: general_dataset/train/nao_folhas/000000324818.jpg
#   inflating: general_dataset/train/nao_folhas/000000324927.jpg
#   inflating: general_dataset/train/nao_folhas/000000325031.jpg
#   inflating: general_dataset/train/nao_folhas/000000325114.jpg
#   inflating: general_dataset/train/nao_folhas/000000325306.jpg
#   inflating: general_dataset/train/nao_folhas/000000325347.jpg
#   inflating: general_dataset/train/nao_folhas/000000325483.jpg
#   inflating: general_dataset/train/nao_folhas/000000325527.jpg
#   inflating: general_dataset/train/nao_folhas/000000325838.jpg
#   inflating: general_dataset/train/nao_folhas/000000325991.jpg
#   inflating: general_dataset/train/nao_folhas/000000326082.jpg
#   inflating: general_dataset/train/nao_folhas/000000326248.jpg
#   inflating: general_dataset/train/nao_folhas/000000326462.jpg
#   inflating: general_dataset/train/nao_folhas/000000326541.jpg
#   inflating: general_dataset/train/nao_folhas/000000326627.jpg
#   inflating: general_dataset/train/nao_folhas/000000326970.jpg
#   inflating: general_dataset/train/nao_folhas/000000327592.jpg
#   inflating: general_dataset/train/nao_folhas/000000327601.jpg
#   inflating: general_dataset/train/nao_folhas/000000327605.jpg
#   inflating: general_dataset/train/nao_folhas/000000327617.jpg
#   inflating: general_dataset/train/nao_folhas/000000327701.jpg
#   inflating: general_dataset/train/nao_folhas/000000327769.jpg
#   inflating: general_dataset/train/nao_folhas/000000327780.jpg
#   inflating: general_dataset/train/nao_folhas/000000327890.jpg
#   inflating: general_dataset/train/nao_folhas/000000328117.jpg
#   inflating: general_dataset/train/nao_folhas/000000328238.jpg
#   inflating: general_dataset/train/nao_folhas/000000328430.jpg
#   inflating: general_dataset/train/nao_folhas/000000328683.jpg
#   inflating: general_dataset/train/nao_folhas/000000328959.jpg
#   inflating: general_dataset/train/nao_folhas/000000329041.jpg
#   inflating: general_dataset/train/nao_folhas/000000329323.jpg
#   inflating: general_dataset/train/nao_folhas/000000329542.jpg
#   inflating: general_dataset/train/nao_folhas/000000329614.jpg
#   inflating: general_dataset/train/nao_folhas/000000329827.jpg
#   inflating: general_dataset/train/nao_folhas/000000330369.jpg
#   inflating: general_dataset/train/nao_folhas/000000330396.jpg
#   inflating: general_dataset/train/nao_folhas/000000330790.jpg
#   inflating: general_dataset/train/nao_folhas/000000330818.jpg
#   inflating: general_dataset/train/nao_folhas/000000331317.jpg
#   inflating: general_dataset/train/nao_folhas/000000331352.jpg
#   inflating: general_dataset/train/nao_folhas/000000331569.jpg
#   inflating: general_dataset/train/nao_folhas/000000331604.jpg
#   inflating: general_dataset/train/nao_folhas/000000331799.jpg
#   inflating: general_dataset/train/nao_folhas/000000332351.jpg
#   inflating: general_dataset/train/nao_folhas/000000332455.jpg
#   inflating: general_dataset/train/nao_folhas/000000332570.jpg
#   inflating: general_dataset/train/nao_folhas/000000332901.jpg
#   inflating: general_dataset/train/nao_folhas/000000333069.jpg
#   inflating: general_dataset/train/nao_folhas/000000333402.jpg
#   inflating: general_dataset/train/nao_folhas/000000333745.jpg
#   inflating: general_dataset/train/nao_folhas/000000333772.jpg
#   inflating: general_dataset/train/nao_folhas/000000333956.jpg
#   inflating: general_dataset/train/nao_folhas/000000334006.jpg
#   inflating: general_dataset/train/nao_folhas/000000334399.jpg
#   inflating: general_dataset/train/nao_folhas/000000334417.jpg
#   inflating: general_dataset/train/nao_folhas/000000334483.jpg
#   inflating: general_dataset/train/nao_folhas/000000334521.jpg
#   inflating: general_dataset/train/nao_folhas/000000334530.jpg
#   inflating: general_dataset/train/nao_folhas/000000334555.jpg
#   inflating: general_dataset/train/nao_folhas/000000334767.jpg
#   inflating: general_dataset/train/nao_folhas/000000334977.jpg
#   inflating: general_dataset/train/nao_folhas/000000335177.jpg
#   inflating: general_dataset/train/nao_folhas/000000335328.jpg
#   inflating: general_dataset/train/nao_folhas/000000335427.jpg
#   inflating: general_dataset/train/nao_folhas/000000335450.jpg
#   inflating: general_dataset/train/nao_folhas/000000335529.jpg
#   inflating: general_dataset/train/nao_folhas/000000335658.jpg
#   inflating: general_dataset/train/nao_folhas/000000335800.jpg
#   inflating: general_dataset/train/nao_folhas/000000336053.jpg
#   inflating: general_dataset/train/nao_folhas/000000336209.jpg
#   inflating: general_dataset/train/nao_folhas/000000336232.jpg
#   inflating: general_dataset/train/nao_folhas/000000336265.jpg
#   inflating: general_dataset/train/nao_folhas/000000336628.jpg
#   inflating: general_dataset/train/nao_folhas/000000336658.jpg
#   inflating: general_dataset/train/nao_folhas/000000337055.jpg
#   inflating: general_dataset/train/nao_folhas/000000337498.jpg
#   inflating: general_dataset/train/nao_folhas/000000337987.jpg
#   inflating: general_dataset/train/nao_folhas/000000338219.jpg
#   inflating: general_dataset/train/nao_folhas/000000338428.jpg
#   inflating: general_dataset/train/nao_folhas/000000338532.jpg
#   inflating: general_dataset/train/nao_folhas/000000338560.jpg
#   inflating: general_dataset/train/nao_folhas/000000338624.jpg
#   inflating: general_dataset/train/nao_folhas/000000338625.jpg
#   inflating: general_dataset/train/nao_folhas/000000338718.jpg
#   inflating: general_dataset/train/nao_folhas/000000338905.jpg
#   inflating: general_dataset/train/nao_folhas/000000339442.jpg
#   inflating: general_dataset/train/nao_folhas/000000339870.jpg
#   inflating: general_dataset/train/nao_folhas/000000340175.jpg
#   inflating: general_dataset/train/nao_folhas/000000340272.jpg
#   inflating: general_dataset/train/nao_folhas/000000340451.jpg
#   inflating: general_dataset/train/nao_folhas/000000340697.jpg
#   inflating: general_dataset/train/nao_folhas/000000340930.jpg
#   inflating: general_dataset/train/nao_folhas/000000341058.jpg
#   inflating: general_dataset/train/nao_folhas/000000341094.jpg
#   inflating: general_dataset/train/nao_folhas/000000341196.jpg
#   inflating: general_dataset/train/nao_folhas/000000341719.jpg
#   inflating: general_dataset/train/nao_folhas/000000341921.jpg
#   inflating: general_dataset/train/nao_folhas/000000341973.jpg
#   inflating: general_dataset/train/nao_folhas/000000342006.jpg
#   inflating: general_dataset/train/nao_folhas/000000342128.jpg
#   inflating: general_dataset/train/nao_folhas/000000342367.jpg
#   inflating: general_dataset/train/nao_folhas/000000342971.jpg
#   inflating: general_dataset/train/nao_folhas/000000343076.jpg
#   inflating: general_dataset/train/nao_folhas/000000343149.jpg
#   inflating: general_dataset/train/nao_folhas/000000343218.jpg
#   inflating: general_dataset/train/nao_folhas/000000343315.jpg
#   inflating: general_dataset/train/nao_folhas/000000343496.jpg
#   inflating: general_dataset/train/nao_folhas/000000343524.jpg
#   inflating: general_dataset/train/nao_folhas/000000343561.jpg
#   inflating: general_dataset/train/nao_folhas/000000343706.jpg
#   inflating: general_dataset/train/nao_folhas/000000343803.jpg
#   inflating: general_dataset/train/nao_folhas/000000343937.jpg
#   inflating: general_dataset/train/nao_folhas/000000344059.jpg
#   inflating: general_dataset/train/nao_folhas/000000344100.jpg
#   inflating: general_dataset/train/nao_folhas/000000344268.jpg
#   inflating: general_dataset/train/nao_folhas/000000344611.jpg
#   inflating: general_dataset/train/nao_folhas/000000344614.jpg
#   inflating: general_dataset/train/nao_folhas/000000344621.jpg
#   inflating: general_dataset/train/nao_folhas/000000344795.jpg
#   inflating: general_dataset/train/nao_folhas/000000344888.jpg
#   inflating: general_dataset/train/nao_folhas/000000344909.jpg
#   inflating: general_dataset/train/nao_folhas/000000345252.jpg
#   inflating: general_dataset/train/nao_folhas/000000345356.jpg
#   inflating: general_dataset/train/nao_folhas/000000345361.jpg
#   inflating: general_dataset/train/nao_folhas/000000345385.jpg
#   inflating: general_dataset/train/nao_folhas/000000345397.jpg
#   inflating: general_dataset/train/nao_folhas/000000345466.jpg
#   inflating: general_dataset/train/nao_folhas/000000345941.jpg
#   inflating: general_dataset/train/nao_folhas/000000346638.jpg
#   inflating: general_dataset/train/nao_folhas/000000346707.jpg
#   inflating: general_dataset/train/nao_folhas/000000346905.jpg
#   inflating: general_dataset/train/nao_folhas/000000346968.jpg
#   inflating: general_dataset/train/nao_folhas/000000347163.jpg
#   inflating: general_dataset/train/nao_folhas/000000347174.jpg
#   inflating: general_dataset/train/nao_folhas/000000347265.jpg
#   inflating: general_dataset/train/nao_folhas/000000347335.jpg
#   inflating: general_dataset/train/nao_folhas/000000347370.jpg
#   inflating: general_dataset/train/nao_folhas/000000347544.jpg
#   inflating: general_dataset/train/nao_folhas/000000347664.jpg
#   inflating: general_dataset/train/nao_folhas/000000347930.jpg
#   inflating: general_dataset/train/nao_folhas/000000348012.jpg
#   inflating: general_dataset/train/nao_folhas/000000348045.jpg
#   inflating: general_dataset/train/nao_folhas/000000348216.jpg
#   inflating: general_dataset/train/nao_folhas/000000348243.jpg
#   inflating: general_dataset/train/nao_folhas/000000348488.jpg
#   inflating: general_dataset/train/nao_folhas/000000348881.jpg
#   inflating: general_dataset/train/nao_folhas/000000349184.jpg
#   inflating: general_dataset/train/nao_folhas/000000349480.jpg
#   inflating: general_dataset/train/nao_folhas/000000349594.jpg
#   inflating: general_dataset/train/nao_folhas/000000349678.jpg
#   inflating: general_dataset/train/nao_folhas/000000349837.jpg
#   inflating: general_dataset/train/nao_folhas/000000350003.jpg
#   inflating: general_dataset/train/nao_folhas/000000350019.jpg
#   inflating: general_dataset/train/nao_folhas/000000350054.jpg
#   inflating: general_dataset/train/nao_folhas/000000350148.jpg
#   inflating: general_dataset/train/nao_folhas/000000350388.jpg
#   inflating: general_dataset/train/nao_folhas/000000350405.jpg
#   inflating: general_dataset/train/nao_folhas/000000350833.jpg
#   inflating: general_dataset/train/nao_folhas/000000351096.jpg
#   inflating: general_dataset/train/nao_folhas/000000351331.jpg
#   inflating: general_dataset/train/nao_folhas/000000351530.jpg
#   inflating: general_dataset/train/nao_folhas/000000351589.jpg
#   inflating: general_dataset/train/nao_folhas/000000351609.jpg
#   inflating: general_dataset/train/nao_folhas/000000351810.jpg
#   inflating: general_dataset/train/nao_folhas/000000351823.jpg
#   inflating: general_dataset/train/nao_folhas/000000352491.jpg
#   inflating: general_dataset/train/nao_folhas/000000352584.jpg
#   inflating: general_dataset/train/nao_folhas/000000352618.jpg
#   inflating: general_dataset/train/nao_folhas/000000352760.jpg
#   inflating: general_dataset/train/nao_folhas/000000352900.jpg
#   inflating: general_dataset/train/nao_folhas/000000353051.jpg
#   inflating: general_dataset/train/nao_folhas/000000353180.jpg
#   inflating: general_dataset/train/nao_folhas/000000353518.jpg
#   inflating: general_dataset/train/nao_folhas/000000354072.jpg
#   inflating: general_dataset/train/nao_folhas/000000354307.jpg
#   inflating: general_dataset/train/nao_folhas/000000354547.jpg
#   inflating: general_dataset/train/nao_folhas/000000354753.jpg
#   inflating: general_dataset/train/nao_folhas/000000354829.jpg
#   inflating: general_dataset/train/nao_folhas/000000355677.jpg
#   inflating: general_dataset/train/nao_folhas/000000355817.jpg
#   inflating: general_dataset/train/nao_folhas/000000356094.jpg
#   inflating: general_dataset/train/nao_folhas/000000356125.jpg
#   inflating: general_dataset/train/nao_folhas/000000356169.jpg
#   inflating: general_dataset/train/nao_folhas/000000356248.jpg
#   inflating: general_dataset/train/nao_folhas/000000356261.jpg
#   inflating: general_dataset/train/nao_folhas/000000356387.jpg
#   inflating: general_dataset/train/nao_folhas/000000356424.jpg
#   inflating: general_dataset/train/nao_folhas/000000356427.jpg
#   inflating: general_dataset/train/nao_folhas/000000356428.jpg
#   inflating: general_dataset/train/nao_folhas/000000356432.jpg
#   inflating: general_dataset/train/nao_folhas/000000356498.jpg
#   inflating: general_dataset/train/nao_folhas/000000356505.jpg
#   inflating: general_dataset/train/nao_folhas/000000356612.jpg
#   inflating: general_dataset/train/nao_folhas/000000356968.jpg
#   inflating: general_dataset/train/nao_folhas/000000357060.jpg
#   inflating: general_dataset/train/nao_folhas/000000357081.jpg
#   inflating: general_dataset/train/nao_folhas/000000357238.jpg
#   inflating: general_dataset/train/nao_folhas/000000357430.jpg
#   inflating: general_dataset/train/nao_folhas/000000357459.jpg
#   inflating: general_dataset/train/nao_folhas/000000357501.jpg
#   inflating: general_dataset/train/nao_folhas/000000357737.jpg
#   inflating: general_dataset/train/nao_folhas/000000357742.jpg
#   inflating: general_dataset/train/nao_folhas/000000357748.jpg
#   inflating: general_dataset/train/nao_folhas/000000357816.jpg
#   inflating: general_dataset/train/nao_folhas/000000357888.jpg
#   inflating: general_dataset/train/nao_folhas/000000357903.jpg
#   inflating: general_dataset/train/nao_folhas/000000359219.jpg
#   inflating: general_dataset/train/nao_folhas/000000359540.jpg
#   inflating: general_dataset/train/nao_folhas/000000359677.jpg
#   inflating: general_dataset/train/nao_folhas/000000359781.jpg
#   inflating: general_dataset/train/nao_folhas/000000359855.jpg
#   inflating: general_dataset/train/nao_folhas/000000359937.jpg
#   inflating: general_dataset/train/nao_folhas/000000360325.jpg
#   inflating: general_dataset/train/nao_folhas/000000360393.jpg
#   inflating: general_dataset/train/nao_folhas/000000360661.jpg
#   inflating: general_dataset/train/nao_folhas/000000360951.jpg
#   inflating: general_dataset/train/nao_folhas/000000360960.jpg
#   inflating: general_dataset/train/nao_folhas/000000361142.jpg
#   inflating: general_dataset/train/nao_folhas/000000361147.jpg
#   inflating: general_dataset/train/nao_folhas/000000361180.jpg
#   inflating: general_dataset/train/nao_folhas/000000361238.jpg
#   inflating: general_dataset/train/nao_folhas/000000361268.jpg
#   inflating: general_dataset/train/nao_folhas/000000361506.jpg
#   inflating: general_dataset/train/nao_folhas/000000361551.jpg
#   inflating: general_dataset/train/nao_folhas/000000361586.jpg
#   inflating: general_dataset/train/nao_folhas/000000361730.jpg
#   inflating: general_dataset/train/nao_folhas/000000361919.jpg
#   inflating: general_dataset/train/nao_folhas/000000362434.jpg
#   inflating: general_dataset/train/nao_folhas/000000362520.jpg
#   inflating: general_dataset/train/nao_folhas/000000362682.jpg
#   inflating: general_dataset/train/nao_folhas/000000362716.jpg
#   inflating: general_dataset/train/nao_folhas/000000363072.jpg
#   inflating: general_dataset/train/nao_folhas/000000363461.jpg
#   inflating: general_dataset/train/nao_folhas/000000363666.jpg
#   inflating: general_dataset/train/nao_folhas/000000363840.jpg
#   inflating: general_dataset/train/nao_folhas/000000363875.jpg
#   inflating: general_dataset/train/nao_folhas/000000364102.jpg
#   inflating: general_dataset/train/nao_folhas/000000364126.jpg
#   inflating: general_dataset/train/nao_folhas/000000364166.jpg
#   inflating: general_dataset/train/nao_folhas/000000364322.jpg
#   inflating: general_dataset/train/nao_folhas/000000364557.jpg
#   inflating: general_dataset/train/nao_folhas/000000364636.jpg
#   inflating: general_dataset/train/nao_folhas/000000364884.jpg
#   inflating: general_dataset/train/nao_folhas/000000365098.jpg
#   inflating: general_dataset/train/nao_folhas/000000365207.jpg
#   inflating: general_dataset/train/nao_folhas/000000365208.jpg
#   inflating: general_dataset/train/nao_folhas/000000365387.jpg
#   inflating: general_dataset/train/nao_folhas/000000365521.jpg
#   inflating: general_dataset/train/nao_folhas/000000365642.jpg
#   inflating: general_dataset/train/nao_folhas/000000365745.jpg
#   inflating: general_dataset/train/nao_folhas/000000365886.jpg
#   inflating: general_dataset/train/nao_folhas/000000366141.jpg
#   inflating: general_dataset/train/nao_folhas/000000366178.jpg
#   inflating: general_dataset/train/nao_folhas/000000366199.jpg
#   inflating: general_dataset/train/nao_folhas/000000366225.jpg
#   inflating: general_dataset/train/nao_folhas/000000366711.jpg
#   inflating: general_dataset/train/nao_folhas/000000366884.jpg
#   inflating: general_dataset/train/nao_folhas/000000367095.jpg
#   inflating: general_dataset/train/nao_folhas/000000367228.jpg
#   inflating: general_dataset/train/nao_folhas/000000367569.jpg
#   inflating: general_dataset/train/nao_folhas/000000367680.jpg
#   inflating: general_dataset/train/nao_folhas/000000368038.jpg
#   inflating: general_dataset/train/nao_folhas/000000368212.jpg
#   inflating: general_dataset/train/nao_folhas/000000368294.jpg
#   inflating: general_dataset/train/nao_folhas/000000368335.jpg
#   inflating: general_dataset/train/nao_folhas/000000368684.jpg
#   inflating: general_dataset/train/nao_folhas/000000368752.jpg
#   inflating: general_dataset/train/nao_folhas/000000368900.jpg
#   inflating: general_dataset/train/nao_folhas/000000368940.jpg
#   inflating: general_dataset/train/nao_folhas/000000368961.jpg
#   inflating: general_dataset/train/nao_folhas/000000368982.jpg
#   inflating: general_dataset/train/nao_folhas/000000369323.jpg
#   inflating: general_dataset/train/nao_folhas/000000369370.jpg
#   inflating: general_dataset/train/nao_folhas/000000369503.jpg
#   inflating: general_dataset/train/nao_folhas/000000369541.jpg
#   inflating: general_dataset/train/nao_folhas/000000369751.jpg
#   inflating: general_dataset/train/nao_folhas/000000369757.jpg
#   inflating: general_dataset/train/nao_folhas/000000369771.jpg
#   inflating: general_dataset/train/nao_folhas/000000369812.jpg
#   inflating: general_dataset/train/nao_folhas/000000370042.jpg
#   inflating: general_dataset/train/nao_folhas/000000370208.jpg
#   inflating: general_dataset/train/nao_folhas/000000370270.jpg
#   inflating: general_dataset/train/nao_folhas/000000370478.jpg
#   inflating: general_dataset/train/nao_folhas/000000370677.jpg
#   inflating: general_dataset/train/nao_folhas/000000370711.jpg
#   inflating: general_dataset/train/nao_folhas/000000370813.jpg
#   inflating: general_dataset/train/nao_folhas/000000370818.jpg
#   inflating: general_dataset/train/nao_folhas/000000371472.jpg
#   inflating: general_dataset/train/nao_folhas/000000371552.jpg
#   inflating: general_dataset/train/nao_folhas/000000371677.jpg
#   inflating: general_dataset/train/nao_folhas/000000371749.jpg
#   inflating: general_dataset/train/nao_folhas/000000372203.jpg
#   inflating: general_dataset/train/nao_folhas/000000372260.jpg
#   inflating: general_dataset/train/nao_folhas/000000372307.jpg
#   inflating: general_dataset/train/nao_folhas/000000372317.jpg
#   inflating: general_dataset/train/nao_folhas/000000372349.jpg
#   inflating: general_dataset/train/nao_folhas/000000372466.jpg
#   inflating: general_dataset/train/nao_folhas/000000372577.jpg
#   inflating: general_dataset/train/nao_folhas/000000372718.jpg
#   inflating: general_dataset/train/nao_folhas/000000373315.jpg
#   inflating: general_dataset/train/nao_folhas/000000373353.jpg
#   inflating: general_dataset/train/nao_folhas/000000373382.jpg
#   inflating: general_dataset/train/nao_folhas/000000373705.jpg
#   inflating: general_dataset/train/nao_folhas/000000374052.jpg
#   inflating: general_dataset/train/nao_folhas/000000374083.jpg
#   inflating: general_dataset/train/nao_folhas/000000374727.jpg
#   inflating: general_dataset/train/nao_folhas/000000374982.jpg
#   inflating: general_dataset/train/nao_folhas/000000375278.jpg
#   inflating: general_dataset/train/nao_folhas/000000375430.jpg
#   inflating: general_dataset/train/nao_folhas/000000375469.jpg
#   inflating: general_dataset/train/nao_folhas/000000375763.jpg
#   inflating: general_dataset/train/nao_folhas/000000376093.jpg
#   inflating: general_dataset/train/nao_folhas/000000376112.jpg
#   inflating: general_dataset/train/nao_folhas/000000376206.jpg
#   inflating: general_dataset/train/nao_folhas/000000376278.jpg
#   inflating: general_dataset/train/nao_folhas/000000376307.jpg
#   inflating: general_dataset/train/nao_folhas/000000376310.jpg
#   inflating: general_dataset/train/nao_folhas/000000376322.jpg
#   inflating: general_dataset/train/nao_folhas/000000376365.jpg
#   inflating: general_dataset/train/nao_folhas/000000376442.jpg
#   inflating: general_dataset/train/nao_folhas/000000376625.jpg
#   inflating: general_dataset/train/nao_folhas/000000376900.jpg
#   inflating: general_dataset/train/nao_folhas/000000377239.jpg
#   inflating: general_dataset/train/nao_folhas/000000377393.jpg
#   inflating: general_dataset/train/nao_folhas/000000377497.jpg
#   inflating: general_dataset/train/nao_folhas/000000377575.jpg
#   inflating: general_dataset/train/nao_folhas/000000377635.jpg
#   inflating: general_dataset/train/nao_folhas/000000377723.jpg
#   inflating: general_dataset/train/nao_folhas/000000377882.jpg
#   inflating: general_dataset/train/nao_folhas/000000378139.jpg
#   inflating: general_dataset/train/nao_folhas/000000378244.jpg
#   inflating: general_dataset/train/nao_folhas/000000378284.jpg
#   inflating: general_dataset/train/nao_folhas/000000378454.jpg
#   inflating: general_dataset/train/nao_folhas/000000378515.jpg
#   inflating: general_dataset/train/nao_folhas/000000378605.jpg
#   inflating: general_dataset/train/nao_folhas/000000378673.jpg
#   inflating: general_dataset/train/nao_folhas/000000379332.jpg
#   inflating: general_dataset/train/nao_folhas/000000379441.jpg
#   inflating: general_dataset/train/nao_folhas/000000379453.jpg
#   inflating: general_dataset/train/nao_folhas/000000379476.jpg
#   inflating: general_dataset/train/nao_folhas/000000379533.jpg
#   inflating: general_dataset/train/nao_folhas/000000380203.jpg
#   inflating: general_dataset/train/nao_folhas/000000380913.jpg
#   inflating: general_dataset/train/nao_folhas/000000381360.jpg
#   inflating: general_dataset/train/nao_folhas/000000381587.jpg
#   inflating: general_dataset/train/nao_folhas/000000381639.jpg
#   inflating: general_dataset/train/nao_folhas/000000382030.jpg
#   inflating: general_dataset/train/nao_folhas/000000382088.jpg
#   inflating: general_dataset/train/nao_folhas/000000382111.jpg
#   inflating: general_dataset/train/nao_folhas/000000382125.jpg
#   inflating: general_dataset/train/nao_folhas/000000382696.jpg
#   inflating: general_dataset/train/nao_folhas/000000382734.jpg
#   inflating: general_dataset/train/nao_folhas/000000382743.jpg
#   inflating: general_dataset/train/nao_folhas/000000383337.jpg
#   inflating: general_dataset/train/nao_folhas/000000383339.jpg
#   inflating: general_dataset/train/nao_folhas/000000383384.jpg
#   inflating: general_dataset/train/nao_folhas/000000383386.jpg
#   inflating: general_dataset/train/nao_folhas/000000383621.jpg
#   inflating: general_dataset/train/nao_folhas/000000383676.jpg
#   inflating: general_dataset/train/nao_folhas/000000383838.jpg
#   inflating: general_dataset/train/nao_folhas/000000383842.jpg
#   inflating: general_dataset/train/nao_folhas/000000383921.jpg
#   inflating: general_dataset/train/nao_folhas/000000384136.jpg
#   inflating: general_dataset/train/nao_folhas/000000384350.jpg
#   inflating: general_dataset/train/nao_folhas/000000384468.jpg
#   inflating: general_dataset/train/nao_folhas/000000384513.jpg
#   inflating: general_dataset/train/nao_folhas/000000384527.jpg
#   inflating: general_dataset/train/nao_folhas/000000384651.jpg
#   inflating: general_dataset/train/nao_folhas/000000384670.jpg
#   inflating: general_dataset/train/nao_folhas/000000384808.jpg
#   inflating: general_dataset/train/nao_folhas/000000384850.jpg
#   inflating: general_dataset/train/nao_folhas/000000385190.jpg
#   inflating: general_dataset/train/nao_folhas/000000385997.jpg
#   inflating: general_dataset/train/nao_folhas/000000386210.jpg
#   inflating: general_dataset/train/nao_folhas/000000386277.jpg
#   inflating: general_dataset/train/nao_folhas/000000386352.jpg
#   inflating: general_dataset/train/nao_folhas/000000386457.jpg
#   inflating: general_dataset/train/nao_folhas/000000386912.jpg
#   inflating: general_dataset/train/nao_folhas/000000387098.jpg
#   inflating: general_dataset/train/nao_folhas/000000387148.jpg
#   inflating: general_dataset/train/nao_folhas/000000387383.jpg
#   inflating: general_dataset/train/nao_folhas/000000387387.jpg
#   inflating: general_dataset/train/nao_folhas/000000387916.jpg
#   inflating: general_dataset/train/nao_folhas/000000388056.jpg
#   inflating: general_dataset/train/nao_folhas/000000388215.jpg
#   inflating: general_dataset/train/nao_folhas/000000388927.jpg
#   inflating: general_dataset/train/nao_folhas/000000389109.jpg
#   inflating: general_dataset/train/nao_folhas/000000389197.jpg
#   inflating: general_dataset/train/nao_folhas/000000389316.jpg
#   inflating: general_dataset/train/nao_folhas/000000389451.jpg
#   inflating: general_dataset/train/nao_folhas/000000389684.jpg
#   inflating: general_dataset/train/nao_folhas/000000389812.jpg
#   inflating: general_dataset/train/nao_folhas/000000389933.jpg
#   inflating: general_dataset/train/nao_folhas/000000390246.jpg
#   inflating: general_dataset/train/nao_folhas/000000390826.jpg
#   inflating: general_dataset/train/nao_folhas/000000390902.jpg
#   inflating: general_dataset/train/nao_folhas/000000391140.jpg
#   inflating: general_dataset/train/nao_folhas/000000391144.jpg
#   inflating: general_dataset/train/nao_folhas/000000391290.jpg
#   inflating: general_dataset/train/nao_folhas/000000391375.jpg
#   inflating: general_dataset/train/nao_folhas/000000391648.jpg
#   inflating: general_dataset/train/nao_folhas/000000392228.jpg
#   inflating: general_dataset/train/nao_folhas/000000392481.jpg
#   inflating: general_dataset/train/nao_folhas/000000392722.jpg
#   inflating: general_dataset/train/nao_folhas/000000392818.jpg
#   inflating: general_dataset/train/nao_folhas/000000392933.jpg
#   inflating: general_dataset/train/nao_folhas/000000393014.jpg
#   inflating: general_dataset/train/nao_folhas/000000393056.jpg
#   inflating: general_dataset/train/nao_folhas/000000393093.jpg
#   inflating: general_dataset/train/nao_folhas/000000393115.jpg
#   inflating: general_dataset/train/nao_folhas/000000393226.jpg
#   inflating: general_dataset/train/nao_folhas/000000393282.jpg
#   inflating: general_dataset/train/nao_folhas/000000393569.jpg
#   inflating: general_dataset/train/nao_folhas/000000393838.jpg
#   inflating: general_dataset/train/nao_folhas/000000394206.jpg
#   inflating: general_dataset/train/nao_folhas/000000394275.jpg
#   inflating: general_dataset/train/nao_folhas/000000394510.jpg
#   inflating: general_dataset/train/nao_folhas/000000394559.jpg
#   inflating: general_dataset/train/nao_folhas/000000394611.jpg
#   inflating: general_dataset/train/nao_folhas/000000394677.jpg
#   inflating: general_dataset/train/nao_folhas/000000394940.jpg
#   inflating: general_dataset/train/nao_folhas/000000395180.jpg
#   inflating: general_dataset/train/nao_folhas/000000395388.jpg
#   inflating: general_dataset/train/nao_folhas/000000395575.jpg
#   inflating: general_dataset/train/nao_folhas/000000395633.jpg
#   inflating: general_dataset/train/nao_folhas/000000395801.jpg
#   inflating: general_dataset/train/nao_folhas/000000396200.jpg
#   inflating: general_dataset/train/nao_folhas/000000396205.jpg
#   inflating: general_dataset/train/nao_folhas/000000396338.jpg
#   inflating: general_dataset/train/nao_folhas/000000396526.jpg
#   inflating: general_dataset/train/nao_folhas/000000396568.jpg
#   inflating: general_dataset/train/nao_folhas/000000396580.jpg
#   inflating: general_dataset/train/nao_folhas/000000396729.jpg
#   inflating: general_dataset/train/nao_folhas/000000396863.jpg
#   inflating: general_dataset/train/nao_folhas/000000396903.jpg
#   inflating: general_dataset/train/nao_folhas/000000397133.jpg
# ...
#   inflating: general_dataset/valid/nao_folhas/000000459396.jpg
#   inflating: general_dataset/valid/nao_folhas/000000459634.jpg
#   inflating: general_dataset/valid/nao_folhas/000000459809.jpg
#   inflating: general_dataset/valid/nao_folhas/000000460929.jpg
#   inflating: general_dataset/valid/nao_folhas/000000461036.jpg
#   inflating: general_dataset/valid/nao_folhas/000000461275.jpg
#   inflating: general_dataset/valid/nao_folhas/000000462728.jpg
#   inflating: general_dataset/valid/nao_folhas/000000463037.jpg
#   inflating: general_dataset/valid/nao_folhas/000000463199.jpg
#   inflating: general_dataset/valid/nao_folhas/000000463542.jpg
#   inflating: general_dataset/valid/nao_folhas/000000463730.jpg
#   inflating: general_dataset/valid/nao_folhas/000000463849.jpg
#   inflating: general_dataset/valid/nao_folhas/000000464089.jpg
#   inflating: general_dataset/valid/nao_folhas/000000464144.jpg
#   inflating: general_dataset/valid/nao_folhas/000000464358.jpg
#   inflating: general_dataset/valid/nao_folhas/000000464824.jpg
#   inflating: general_dataset/valid/nao_folhas/000000465129.jpg
#   inflating: general_dataset/valid/nao_folhas/000000465179.jpg
#   inflating: general_dataset/valid/nao_folhas/000000465585.jpg
#   inflating: general_dataset/valid/nao_folhas/000000465822.jpg
#   inflating: general_dataset/valid/nao_folhas/000000466125.jpg
#   inflating: general_dataset/valid/nao_folhas/000000466567.jpg
#   inflating: general_dataset/valid/nao_folhas/000000466602.jpg
#   inflating: general_dataset/valid/nao_folhas/000000468124.jpg
#   inflating: general_dataset/valid/nao_folhas/000000468965.jpg
#   inflating: general_dataset/valid/nao_folhas/000000469067.jpg
#   inflating: general_dataset/valid/nao_folhas/000000469174.jpg
#   inflating: general_dataset/valid/nao_folhas/000000469192.jpg
#   inflating: general_dataset/valid/nao_folhas/000000469652.jpg
#   inflating: general_dataset/valid/nao_folhas/000000471567.jpg
#   inflating: general_dataset/valid/nao_folhas/000000471893.jpg
#   inflating: general_dataset/valid/nao_folhas/000000471991.jpg
#   inflating: general_dataset/valid/nao_folhas/000000472678.jpg
#   inflating: general_dataset/valid/nao_folhas/000000473015.jpg
#   inflating: general_dataset/valid/nao_folhas/000000474095.jpg
#   inflating: general_dataset/valid/nao_folhas/000000474293.jpg
#   inflating: general_dataset/valid/nao_folhas/000000474344.jpg
#   inflating: general_dataset/valid/nao_folhas/000000475223.jpg
#   inflating: general_dataset/valid/nao_folhas/000000475678.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476119.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476258.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476415.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476704.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476770.jpg
#   inflating: general_dataset/valid/nao_folhas/000000476810.jpg
#   inflating: general_dataset/valid/nao_folhas/000000477441.jpg
#   inflating: general_dataset/valid/nao_folhas/000000478474.jpg
#   inflating: general_dataset/valid/nao_folhas/000000479126.jpg
#   inflating: general_dataset/valid/nao_folhas/000000479155.jpg
#   inflating: general_dataset/valid/nao_folhas/000000479448.jpg
#   inflating: general_dataset/valid/nao_folhas/000000479596.jpg
#   inflating: general_dataset/valid/nao_folhas/000000479953.jpg
#   inflating: general_dataset/valid/nao_folhas/000000480275.jpg
#   inflating: general_dataset/valid/nao_folhas/000000480944.jpg
#   inflating: general_dataset/valid/nao_folhas/000000481390.jpg
#   inflating: general_dataset/valid/nao_folhas/000000481413.jpg
#   inflating: general_dataset/valid/nao_folhas/000000482436.jpg
#   inflating: general_dataset/valid/nao_folhas/000000482800.jpg
#   inflating: general_dataset/valid/nao_folhas/000000482970.jpg
#   inflating: general_dataset/valid/nao_folhas/000000485237.jpg
#   inflating: general_dataset/valid/nao_folhas/000000488592.jpg
#   inflating: general_dataset/valid/nao_folhas/000000489924.jpg
#   inflating: general_dataset/valid/nao_folhas/000000490125.jpg
#   inflating: general_dataset/valid/nao_folhas/000000490171.jpg
#   inflating: general_dataset/valid/nao_folhas/000000491071.jpg
#   inflating: general_dataset/valid/nao_folhas/000000491090.jpg
#   inflating: general_dataset/valid/nao_folhas/000000491216.jpg
#   inflating: general_dataset/valid/nao_folhas/000000491725.jpg
#   inflating: general_dataset/valid/nao_folhas/000000492282.jpg
#   inflating: general_dataset/valid/nao_folhas/000000492968.jpg
#   inflating: general_dataset/valid/nao_folhas/000000493334.jpg
#   inflating: general_dataset/valid/nao_folhas/000000493566.jpg
#   inflating: general_dataset/valid/nao_folhas/000000494427.jpg
#   inflating: general_dataset/valid/nao_folhas/000000494634.jpg
#   inflating: general_dataset/valid/nao_folhas/000000494759.jpg
#   inflating: general_dataset/valid/nao_folhas/000000496597.jpg
#   inflating: general_dataset/valid/nao_folhas/000000497568.jpg
#   inflating: general_dataset/valid/nao_folhas/000000497867.jpg
#   inflating: general_dataset/valid/nao_folhas/000000498709.jpg
#   inflating: general_dataset/valid/nao_folhas/000000499109.jpg
#   inflating: general_dataset/valid/nao_folhas/000000499181.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500049.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500257.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500270.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500464.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500565.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500613.jpg
#   inflating: general_dataset/valid/nao_folhas/000000500716.jpg
#   inflating: general_dataset/valid/nao_folhas/000000501005.jpg
#   inflating: general_dataset/valid/nao_folhas/000000501023.jpg
#   inflating: general_dataset/valid/nao_folhas/000000502136.jpg
#   inflating: general_dataset/valid/nao_folhas/000000502347.jpg
#   inflating: general_dataset/valid/nao_folhas/000000502737.jpg
#   inflating: general_dataset/valid/nao_folhas/000000502910.jpg
#   inflating: general_dataset/valid/nao_folhas/000000503755.jpg
#   inflating: general_dataset/valid/nao_folhas/000000503823.jpg
#   inflating: general_dataset/valid/nao_folhas/000000503841.jpg
#   inflating: general_dataset/valid/nao_folhas/000000504635.jpg
#   inflating: general_dataset/valid/nao_folhas/000000505638.jpg
#   inflating: general_dataset/valid/nao_folhas/000000506004.jpg
#   inflating: general_dataset/valid/nao_folhas/000000506656.jpg
#   inflating: general_dataset/valid/nao_folhas/000000507037.jpg
#   inflating: general_dataset/valid/nao_folhas/000000507575.jpg
#   inflating: general_dataset/valid/nao_folhas/000000507667.jpg
#   inflating: general_dataset/valid/nao_folhas/000000508482.jpg
#   inflating: general_dataset/valid/nao_folhas/000000509008.jpg
#   inflating: general_dataset/valid/nao_folhas/000000511076.jpg
#   inflating: general_dataset/valid/nao_folhas/000000511384.jpg
#   inflating: general_dataset/valid/nao_folhas/000000511647.jpg
#   inflating: general_dataset/valid/nao_folhas/000000511760.jpg
#   inflating: general_dataset/valid/nao_folhas/000000512194.jpg
#   inflating: general_dataset/valid/nao_folhas/000000512403.jpg
#   inflating: general_dataset/valid/nao_folhas/000000514914.jpg
#   inflating: general_dataset/valid/nao_folhas/000000515025.jpg
#   inflating: general_dataset/valid/nao_folhas/000000515445.jpg
#   inflating: general_dataset/valid/nao_folhas/000000515577.jpg
#   inflating: general_dataset/valid/nao_folhas/000000515982.jpg
#   inflating: general_dataset/valid/nao_folhas/000000516677.jpg
#   inflating: general_dataset/valid/nao_folhas/000000516871.jpg
#   inflating: general_dataset/valid/nao_folhas/000000517687.jpg
#   inflating: general_dataset/valid/nao_folhas/000000519338.jpg
#   inflating: general_dataset/valid/nao_folhas/000000519491.jpg
#   inflating: general_dataset/valid/nao_folhas/000000519764.jpg
#   inflating: general_dataset/valid/nao_folhas/000000520077.jpg
#   inflating: general_dataset/valid/nao_folhas/000000520531.jpg
#   inflating: general_dataset/valid/nao_folhas/000000520707.jpg
#   inflating: general_dataset/valid/nao_folhas/000000521141.jpg
#   inflating: general_dataset/valid/nao_folhas/000000521259.jpg
#   inflating: general_dataset/valid/nao_folhas/000000521601.jpg
#   inflating: general_dataset/valid/nao_folhas/000000521819.jpg
#   inflating: general_dataset/valid/nao_folhas/000000522393.jpg
#   inflating: general_dataset/valid/nao_folhas/000000523782.jpg
#   inflating: general_dataset/valid/nao_folhas/000000527029.jpg
#   inflating: general_dataset/valid/nao_folhas/000000527220.jpg
#   inflating: general_dataset/valid/nao_folhas/000000527427.jpg
#   inflating: general_dataset/valid/nao_folhas/000000527616.jpg
#   inflating: general_dataset/valid/nao_folhas/000000528862.jpg
#   inflating: general_dataset/valid/nao_folhas/000000529105.jpg
#   inflating: general_dataset/valid/nao_folhas/000000529568.jpg
#   inflating: general_dataset/valid/nao_folhas/000000529939.jpg
#   inflating: general_dataset/valid/nao_folhas/000000530099.jpg
#   inflating: general_dataset/valid/nao_folhas/000000530162.jpg
#   inflating: general_dataset/valid/nao_folhas/000000530854.jpg
#   inflating: general_dataset/valid/nao_folhas/000000531134.jpg
#   inflating: general_dataset/valid/nao_folhas/000000531135.jpg
#   inflating: general_dataset/valid/nao_folhas/000000531495.jpg
#   inflating: general_dataset/valid/nao_folhas/000000532058.jpg
#   inflating: general_dataset/valid/nao_folhas/000000532575.jpg
#   inflating: general_dataset/valid/nao_folhas/000000533493.jpg
#   inflating: general_dataset/valid/nao_folhas/000000533855.jpg
#   inflating: general_dataset/valid/nao_folhas/000000534270.jpg
#   inflating: general_dataset/valid/nao_folhas/000000534394.jpg
#   inflating: general_dataset/valid/nao_folhas/000000535306.jpg
#   inflating: general_dataset/valid/nao_folhas/000000535858.jpg
#   inflating: general_dataset/valid/nao_folhas/000000536038.jpg
#   inflating: general_dataset/valid/nao_folhas/000000536947.jpg
#   inflating: general_dataset/valid/nao_folhas/000000537802.jpg
#   inflating: general_dataset/valid/nao_folhas/000000538236.jpg
#   inflating: general_dataset/valid/nao_folhas/000000539445.jpg
#   inflating: general_dataset/valid/nao_folhas/000000540414.jpg
#   inflating: general_dataset/valid/nao_folhas/000000540466.jpg
#   inflating: general_dataset/valid/nao_folhas/000000540932.jpg
#   inflating: general_dataset/valid/nao_folhas/000000541952.jpg
#   inflating: general_dataset/valid/nao_folhas/000000542073.jpg
#   inflating: general_dataset/valid/nao_folhas/000000542089.jpg
#   inflating: general_dataset/valid/nao_folhas/000000542423.jpg
#   inflating: general_dataset/valid/nao_folhas/000000542856.jpg
#   inflating: general_dataset/valid/nao_folhas/000000543300.jpg
#   inflating: general_dataset/valid/nao_folhas/000000544444.jpg
#   inflating: general_dataset/valid/nao_folhas/000000544811.jpg
#   inflating: general_dataset/valid/nao_folhas/000000545100.jpg
#   inflating: general_dataset/valid/nao_folhas/000000545594.jpg
#   inflating: general_dataset/valid/nao_folhas/000000546011.jpg
#   inflating: general_dataset/valid/nao_folhas/000000546475.jpg
#   inflating: general_dataset/valid/nao_folhas/000000546659.jpg
#   inflating: general_dataset/valid/nao_folhas/000000547144.jpg
#   inflating: general_dataset/valid/nao_folhas/000000547519.jpg
#   inflating: general_dataset/valid/nao_folhas/000000547854.jpg
#   inflating: general_dataset/valid/nao_folhas/000000548246.jpg
#   inflating: general_dataset/valid/nao_folhas/000000549055.jpg
#   inflating: general_dataset/valid/nao_folhas/000000549136.jpg
#   inflating: general_dataset/valid/nao_folhas/000000549390.jpg
#   inflating: general_dataset/valid/nao_folhas/000000550349.jpg
#   inflating: general_dataset/valid/nao_folhas/000000550426.jpg
#   inflating: general_dataset/valid/nao_folhas/000000551304.jpg
#   inflating: general_dataset/valid/nao_folhas/000000553221.jpg
#   inflating: general_dataset/valid/nao_folhas/000000553339.jpg
#   inflating: general_dataset/valid/nao_folhas/000000553990.jpg
#   inflating: general_dataset/valid/nao_folhas/000000554266.jpg
#   inflating: general_dataset/valid/nao_folhas/000000554328.jpg
#   inflating: general_dataset/valid/nao_folhas/000000554735.jpg
#   inflating: general_dataset/valid/nao_folhas/000000554838.jpg
#   inflating: general_dataset/valid/nao_folhas/000000555012.jpg
#   inflating: general_dataset/valid/nao_folhas/000000555412.jpg
#   inflating: general_dataset/valid/nao_folhas/000000555705.jpg
#   inflating: general_dataset/valid/nao_folhas/000000556498.jpg
#   inflating: general_dataset/valid/nao_folhas/000000556765.jpg
#   inflating: general_dataset/valid/nao_folhas/000000558558.jpg
#   inflating: general_dataset/valid/nao_folhas/000000559099.jpg
#   inflating: general_dataset/valid/nao_folhas/000000559547.jpg
#   inflating: general_dataset/valid/nao_folhas/000000560279.jpg
#   inflating: general_dataset/valid/nao_folhas/000000560880.jpg
#   inflating: general_dataset/valid/nao_folhas/000000561679.jpg
#   inflating: general_dataset/valid/nao_folhas/000000562207.jpg
#   inflating: general_dataset/valid/nao_folhas/000000562561.jpg
#   inflating: general_dataset/valid/nao_folhas/000000563267.jpg
#   inflating: general_dataset/valid/nao_folhas/000000563281.jpg
#   inflating: general_dataset/valid/nao_folhas/000000563349.jpg
#   inflating: general_dataset/valid/nao_folhas/000000564023.jpg
#   inflating: general_dataset/valid/nao_folhas/000000564133.jpg
#   inflating: general_dataset/valid/nao_folhas/000000564336.jpg
#   inflating: general_dataset/valid/nao_folhas/000000565012.jpg
#   inflating: general_dataset/valid/nao_folhas/000000565624.jpg
#   inflating: general_dataset/valid/nao_folhas/000000565778.jpg
#   inflating: general_dataset/valid/nao_folhas/000000566436.jpg
#   inflating: general_dataset/valid/nao_folhas/000000567640.jpg
#   inflating: general_dataset/valid/nao_folhas/000000567740.jpg
#   inflating: general_dataset/valid/nao_folhas/000000567886.jpg
#   inflating: general_dataset/valid/nao_folhas/000000567898.jpg
#   inflating: general_dataset/valid/nao_folhas/000000568690.jpg
#   inflating: general_dataset/valid/nao_folhas/000000568710.jpg
#   inflating: general_dataset/valid/nao_folhas/000000569059.jpg
#   inflating: general_dataset/valid/nao_folhas/000000569700.jpg
#   inflating: general_dataset/valid/nao_folhas/000000569976.jpg
#   inflating: general_dataset/valid/nao_folhas/000000570664.jpg
#   inflating: general_dataset/valid/nao_folhas/000000570688.jpg
#   inflating: general_dataset/valid/nao_folhas/000000570756.jpg
#   inflating: general_dataset/valid/nao_folhas/000000571264.jpg
#   inflating: general_dataset/valid/nao_folhas/000000571718.jpg
#   inflating: general_dataset/valid/nao_folhas/000000571943.jpg
#   inflating: general_dataset/valid/nao_folhas/000000572956.jpg
#   inflating: general_dataset/valid/nao_folhas/000000573008.jpg
#   inflating: general_dataset/valid/nao_folhas/000000573943.jpg
#   inflating: general_dataset/valid/nao_folhas/000000574425.jpg
#   inflating: general_dataset/valid/nao_folhas/000000575500.jpg
#   inflating: general_dataset/valid/nao_folhas/000000575970.jpg
#   inflating: general_dataset/valid/nao_folhas/000000576566.jpg
#   inflating: general_dataset/valid/nao_folhas/000000576654.jpg
#   inflating: general_dataset/valid/nao_folhas/000000578093.jpg
#   inflating: general_dataset/valid/nao_folhas/000000578871.jpg
#   inflating: general_dataset/valid/nao_folhas/000000579091.jpg
#   inflating: general_dataset/valid/nao_folhas/000000579893.jpg
#   inflating: general_dataset/valid/nao_folhas/000000580294.jpg
#   inflating: general_dataset/valid/nao_folhas/000000580418.jpg
#   inflating: general_dataset/valid/nao_folhas/000000581100.jpg
#   inflating: general_dataset/valid/nao_folhas/000000581781.jpg

# %% [markdown]
# # Criar rede CNN

# %% [markdown]
# ## Configurar transformação par pré processamento das imagens

# %%
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomRotation(30),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.6, scale=(0.02, 0.2), ratio=(0.3, 3.3), value=0),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

batch_size = 16

# %% [markdown]
# ## Separar set de treino, teste e validação

# %%
trainset = torchvision.datasets.ImageFolder(root='/content/general_dataset/train',
                                         transform=train_transforms)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2, generator=g)

testset = torchvision.datasets.ImageFolder(root='/content/general_dataset/test',
                                        transform=test_transforms)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=True, num_workers=2, generator=g)

validationset = torchvision.datasets.ImageFolder(root='/content/general_dataset/valid',
                                        transform=test_transforms)
validationloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=True, num_workers=2, generator=g)

classes = ('folhas', 'nao_folhas')

# %%
validationset.classes
# Out:
# ['folhas', 'nao_folhas']

# %% [markdown]
# ### Rede - Criada utilizando transfer learning

# %%
cudnn.benchmark = True
plt.ion()

# %%
class CNN(nn.Module):
  #arquitetura da rede
  def __init__(self, n_classes=10): # Torná-la parametrizável é uma boa prática
    super().__init__()
    self.model = mobilenetv2.mobilenet_v2(weights= MobileNet_V2_Weights.IMAGENET1K_V2)
    for param in self.model.parameters():
      param.requires_grad = False
    for param in list(self.model.features.parameters())[-20:]:
        param.requires_grad = True
    self.model = nn.Sequential(*list(self.model.children())[:-1])
    self.pool = nn.AdaptiveAvgPool2d((1, 1))
    self.fc1 = nn.Linear(1280, 512)
    self.fc2 = nn.Linear(512, 128)
    self.fc4 = nn.Linear(128, 2)
    self.dropout = nn.Dropout(0.5)

  def forward(self, x):
      x = self.model(x)
      x = self.pool(x)
      x = torch.flatten(x, 1)

      x = F.relu(self.fc1(x))
      x = self.dropout(x)

      x = F.relu(self.fc2(x))
      x = self.dropout(x)

      x = self.fc4(x)
      return x

# %% [markdown]
# ## Definindo a função de perda e otimizador

# %%
device = 'cuda' if torch.cuda.is_available() else "cpu"

# %%
cnn = CNN().to(device)

# %%
for param in list(cnn.model.parameters())[-20:]:
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn.parameters(), lr = 0.001)
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)

# %% [markdown]
# ## Treinando o modelo

# %%
print("Número de classes no dataset:", len(trainset.classes))
print("Classes:", trainset.classes)
# Out:
# Número de classes no dataset: 2
# Classes: ['folhas', 'nao_folhas']

# %%
def mixup_data(x, y, alpha=0.8):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
epochs = 50
best_score = float('inf')
early_stop = 5
counter = 0
save_path = "/content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt"

print(f"Iniciando treino com MIXUP (epochs={epochs}, early_stop={early_stop})...")
print(f"O melhor modelo será salvo em: {save_path}")

save_dir = os.path.dirname(save_path)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for epoch in range(epochs):
    print(f"\n--- Epoch {epoch+1}/{epochs} ---")
    print(f"Counter: {counter}/{early_stop} | Best Loss: {best_score:.6f}")

    # --- Treino com MIXUP ---
    cnn.train()
    train_loss = 0.0

    # --- A LINHA CRÍTICA (CORRIGIDA) ---
    # Certifique-se que o 'tqdm' está a "embrulhar" o 'train_loader'
    train = tqdm(trainloader, desc="Treinando (Mixup)")
    # O total de iterações deve ser ~1283, NÃO ~20516

    for data in train:
        inputs, labels = data
        # 'inputs' e 'labels' são AGORA TENSORS DE BATCH
        inputs, labels = inputs.to(device), labels.to(device) # Esta linha vai funcionar

        # --- APLICA O MIXUP ---
        mixed_inputs, labels_a, labels_b, lam = mixup_data(inputs, labels)

        optimizer.zero_grad()
        outputs = cnn(mixed_inputs)

        # --- CALCULA A PERDA DO MIXUP ---
        loss = mixup_criterion(criterion, outputs, labels_a, labels_b, lam)

        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train.set_description('Train Loss: %.6f' % (loss.item()))

    # --- Validação (NÃO USA MIXUP) ---
    cnn.eval()
    validation_loss = 0.0

    # --- A LINHA CRÍTICA (CORRIGIDA) ---
    validation = tqdm(validationloader, desc="Validando")
    # O total de iterações deve ser ~211

    with torch.no_grad():
      for data in validation:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = cnn(inputs)
        loss = criterion(outputs, labels) # Loss normal aqui
        validation_loss += loss.item()
        validation.set_description('Val Loss: %.6f' % (loss.item()))

    # Calcular médias (pelo NÚMERO DE BATCHES, como o seu código original)
    validation_loss = validation_loss / len(validationloader)
    train_loss = train_loss / len(trainloader)

    print(f"Epoch Avg Train Loss: {train_loss:.6f}")
    print(f"Epoch Avg Val Loss:   {validation_loss:.6f}")

    # Lógica do Scheduler
    scheduler.step(validation_loss)

    # Lógica do Early Stopping
    if validation_loss < best_score - 1e-4:
        print(f"Val Loss melhorou! ({best_score:.6f} -> {validation_loss:.6f})")
        print(f"Salvando modelo em: {save_path}")
        torch.save(cnn.state_dict(), save_path)
        best_score = validation_loss
        counter = 0
    else:
        counter += 1
        print(f"Val Loss não melhorou. Counter: {counter}")

    if counter >= early_stop:
        print(f"Early stopping ativado na epoch {epoch+1}!")
        break

print(f'\nTreino Concluído. O melhor modelo (Mixup) está salvo em "{save_path}".')
# Out:
# Iniciando treino com MIXUP (epochs=50, early_stop=5)...
# O melhor modelo será salvo em: /content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt
#
# --- Epoch 1/50 ---
# Counter: 0/5 | Best Loss: inf
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.327303
# Epoch Avg Val Loss:   0.066571
# Val Loss melhorou! (inf -> 0.066571)
# Salvando modelo em: /content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt
#
# --- Epoch 2/50 ---
# Counter: 0/5 | Best Loss: 0.066571
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.293091
# Epoch Avg Val Loss:   0.061184
# Val Loss melhorou! (0.066571 -> 0.061184)
# Salvando modelo em: /content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt
#
# --- Epoch 3/50 ---
# Counter: 0/5 | Best Loss: 0.061184
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.279253
# Epoch Avg Val Loss:   0.071179
# Val Loss não melhorou. Counter: 1
#
# --- Epoch 4/50 ---
# Counter: 1/5 | Best Loss: 0.061184
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.269740
# Epoch Avg Val Loss:   0.077454
# Val Loss não melhorou. Counter: 2
#
# --- Epoch 5/50 ---
# Counter: 2/5 | Best Loss: 0.061184
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.255910
# Epoch Avg Val Loss:   0.072802
# Val Loss não melhorou. Counter: 3
#
# --- Epoch 6/50 ---
# Counter: 3/5 | Best Loss: 0.061184
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.260272
# Epoch Avg Val Loss:   0.049152
# Val Loss melhorou! (0.061184 -> 0.049152)
# Salvando modelo em: /content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt
#
# --- Epoch 7/50 ---
# Counter: 0/5 | Best Loss: 0.049152
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.250795
# Epoch Avg Val Loss:   0.051945
# Val Loss não melhorou. Counter: 1
#
# --- Epoch 8/50 ---
# Counter: 1/5 | Best Loss: 0.049152
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.249275
# Epoch Avg Val Loss:   0.031688
# Val Loss melhorou! (0.049152 -> 0.031688)
# Salvando modelo em: /content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt
#
# --- Epoch 9/50 ---
# Counter: 0/5 | Best Loss: 0.031688
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.254832
# Epoch Avg Val Loss:   0.048584
# Val Loss não melhorou. Counter: 1
#
# --- Epoch 10/50 ---
# Counter: 1/5 | Best Loss: 0.031688
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.245462
# Epoch Avg Val Loss:   0.040769
# Val Loss não melhorou. Counter: 2
#
# --- Epoch 11/50 ---
# Counter: 2/5 | Best Loss: 0.031688
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# : AssertionErrorcan only test a child process
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.242309
# Epoch Avg Val Loss:   0.037629
# Val Loss não melhorou. Counter: 3
#
# --- Epoch 12/50 ---
# Counter: 3/5 | Best Loss: 0.031688
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#       File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#     if w.is_alive():
#
#    File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#         if w.is_alive():
#    ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^
# ^  File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
# ^    ^^assert self._parent_pid == os.getpid(), 'can only test a child process'^^
#
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#      assert self._parent_pid == os.getpid(), 'can only test a child process'
#               ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^AssertionError^: can only test a child process^
#
# AssertionError: can only test a child process
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.246133
# Epoch Avg Val Loss:   0.084842
# Val Loss não melhorou. Counter: 4
#
# --- Epoch 13/50 ---
# Counter: 4/5 | Best Loss: 0.031688
# Treinando (Mixup):   0%|          | 0/718 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7eb353fa80e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1647, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Validando:   0%|          | 0/93 [00:00<?, ?it/s]
# Epoch Avg Train Loss: 0.238752
# Epoch Avg Val Loss:   0.048937
# Val Loss não melhorou. Counter: 5
# Early stopping ativado na epoch 13!
#
# Treino Concluído. O melhor modelo (Mixup) está salvo em "/content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt".

# %%
print(labels)
# Out:
# tensor([1, 1, 0, 0, 1, 1, 0, 1], device='cuda:0')

# %% [markdown]
# ## Testar modelo

# %%
def denormalize(img_tensor):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    img = img_tensor * std + mean  # desfaz a normalização
    return img.clamp(0, 1)  # garante valores válidos

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

fig = plt.figure(figsize=(20, 4))
for idx in np.arange(4):
    ax = fig.add_subplot(2, 4//2, idx + 1, xticks=[], yticks=[])

    # desfaz normalização antes de mostrar
    img = denormalize(images[idx])
    img = img.numpy().transpose(1, 2, 0)

    plt.imshow(img)
    ax.set_title(classes[labels[idx]])

# %%
images = images.to(device)
outputs = cnn(images)
outputs

_, predicted = torch.max(outputs, 1)
print("predicted: ", ' '.join('%5s'% classes[predicted[j]]
                             for j in range(4)))
# Out:
# predicted:  folhas nao_folhas nao_folhas folhas

# %% [markdown]
# ## Performace total do modelo

# %%
best_weights_path = "/content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt"

if os.path.exists(best_weights_path):
    print(f"Carregando os melhores pesos de '{best_weights_path}' para o teste...")
    # Carregar os pesos (map_location garante que funciona na CPU ou GPU)
    pesos = torch.load(best_weights_path, map_location=device)
    # Aplicar os pesos ao seu objeto 'cnn'
    cnn.load_state_dict(pesos)
# Out:
# Carregando os melhores pesos de '/content/drive/MyDrive/Upx_plantas/model/cnn_model_mixup_general.pt' para o teste...

# %%
pred = []
labels_list = []
correct = 0
total = 0
cnn.eval()

with torch.no_grad():
  for data in testloader:
    images, label = data
    images = images.to(device)
    label = label.to(device)

    outputs = cnn(images)
    _, predicted = torch.max(outputs.data, 1)

    pred += predicted.cpu().tolist()
    labels_list += label.cpu().tolist()
    total += label.size(0)

    correct += (predicted == label).sum().item()

accuracy = correct / total
print(f'Accuracy no conjunto de teste: {accuracy:.4f}')
# Out:
# Accuracy no conjunto de teste: 0.9993

# %%
cm = confusion_matrix(labels_list, pred)
ConfusionMatrixDisplay(cm).plot()
